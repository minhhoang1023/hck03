# %%
import pandas as pd
import numpy as np
import utils
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import GradientBoostingRegressor
from tqdm import tqdm_notebook as tqdm

# %%
import utils 
from utils import generate_submission_file, mean_absolute_percentage_error, predict_n_periods, build_target
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import pandas as pd 
import numpy as np 
import statsmodels.api as sm  # <--- Yay! API! 
# %matplotlib inline 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 5)
from statsmodels.tsa.statespace.sarimax import SARIMAX

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)   
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %% [markdown]
# ## Getting clean data

# %%
data = pd.read_csv('data/data.csv')

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data = data.set_index('date')
data = data.sort_index()

# %%
area_1_raw = data[data.variable == 'area_1'].drop('variable', axis = 1).sort_index()
area_2_raw = data[data.variable == 'area_2'].drop('variable', axis = 1).sort_index()
area_3_raw = data[data.variable == 'area_3'].drop('variable', axis = 1).sort_index()

# %%
area_1_raw.plot()
area_2_raw.plot()
area_3_raw.plot()

plt.rcParams['figure.figsize'] = (6, 4)

# %%
area_1 = area_1_raw.dropna()
area_2 = area_2_raw.dropna()
area_3 = area_3_raw.dropna()

# %%
area_1 = (area_1.ffill()+ area_1.bfill())/2
area_2 = (area_2.ffill()+ area_2.bfill())/2
area_3 = (area_3.ffill()+ area_3.bfill())/2

# %%
train_1 = area_1[:-168]
train_2 = area_2[:-168]
train_3 = area_3[:-168]

test_1 = area_1[-168:]
test_2 = area_2[-168:]
test_3 = area_3[-168:]

# %% [markdown]
# ## Build Target

# %%
df_1 = build_target(area_1, 168)
df_1 = build_target(area_2, 168)
df_3 = build_target(area_3, 168)

# %%
train_1 = df_1[:-168]
train_2 = df_1[:-168]
train_3 = df_3[:-168]

test_1 = df_1[-168:]
test_2 = df_1[-168:]
test_3 = df_3[-168:]

# %%
X_train_1 = train_1.drop('target', axis = 1)
X_train_2 = train_2.drop('target', axis = 1)
X_train_3 = train_3.drop('target', axis = 1)

y_train_1 = train_1.target
y_train_2 = train_2.target
y_train_3 = train_3.target

X_test_1 = test_1.drop('target', axis = 1)
X_test_2 = test_2.drop('target', axis = 1)
X_test_3 = test_3.drop('target', axis = 1)

y_test_1 = test_1.target
y_test_2 = test_2.target
y_test_3 = test_3.target

# %% [markdown]
# ## Feature Engineering

# %%
predictions_1 = predict_n_periods(series_=train_1, 
                  n_periods=len(test_1), 
                  model=LinearRegression(), 
                  num_periods_lagged = 24,
                  num_periods_diffed = 0,
                  weekday=True,
                  month=True,
                  monthday=True,
                  rolling=[np.mean,np.min,np.max,np.std]
                  )

# %%
predictions_1 = predict_n_periods(series_=train_2, 
                  n_periods=len(test_2), 
                  model=LinearRegression(), 
                  num_periods_lagged = 24,
                  num_periods_diffed = 0,
                  weekday=True,
                  month=True,
                  monthday=True,
                  rolling=[np.mean,np.min,np.max,np.std]
                  )

# %%
predictions_1 = predict_n_periods(series_=train_3, 
                  n_periods=len(test_3), 
                  model=LinearRegression(), 
                  num_periods_lagged = 24,
                  num_periods_diffed = 0,
                  weekday=True,
                  month=True,
                  monthday=True,
                  rolling=[np.mean,np.min,np.max,np.std]
                  )

# %% [markdown]
# ## Model

# %% [markdown]
# ## Cross Validation

# %%
for ii, (tr, tt) in tqdm(enumerate(cv.split(X)))
# Out:
#   File "<ipython-input-38-d3ad7c779d87>", line 1
#     for ii, (tr, tt) in tqdm(enumerate(cv.split(X)))
#                                                     ^
# SyntaxError: invalid syntax

# %%
def cross_validation(n_splits, train_data, num_periods_lagged, num_periods_diffed, model,
                    weekday, month, monthday, rolling):
    X = train_data
        
    idx_lst = []
    values_lst = []
    
    for ii, (tr, tt) in tqdm(enumerate(cv.split(X))):
        # Fit the model on training data and collect the coefficients
        train = X[tr]
        test = X[tt]
        idx_lst.append(X.index[tt][0])
        error_lst = []
        
        predictions = predict_n_periods(series_=train,
                        n_periods=n_periods, 
                        model=model, 
                        num_periods_lagged=num_periods_lagged,
                        num_periods_diffed=num_periods_diffed,
                        weekday=weekday,
                        month=month,
                        monthday=monthday,
                        rolling=rolling)
        
        values_lst.append(mean_absolute_percentage_error(test,predictions))
    return values_lst

# %%
predictions_1 = cross_validation(n_splits = 10,
                  train_data=train_1, 
                  model=GradientBoostingRegressor(n_estimators=20, learning_rate=0.5), 
                  num_periods_lagged = 24,
                  num_periods_diffed = 0,
                  weekday=True,
                  month=True,
                  monthday=True,
                  rolling=[np.mean,np.min,np.max,np.std]
                  )
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-17172bf8ff2c> in <module>
#       7                   month=True,
#       8                   monthday=True,
# ----> 9                   rolling=[np.mean,np.min,np.max,np.std]
#      10                   )
#
# <ipython-input-30-e6241de1889a> in cross_validation(n_splits, train_data, num_periods_lagged, num_periods_diffed, model, weekday, month, monthday, rolling)
#       8     for ii, (tr, tt) in tqdm(enumerate(cv.split(X))):
#       9         # Fit the model on training data and collect the coefficients
# ---> 10         train = X[tr]
#      11         test = X[tt]
#      12         idx_lst.append(X.index[tt][0])
#
# ~\Anaconda3\envs\HCKT03\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
# ...

# %%
# Create time-series cross-validation object
cv = TimeSeriesSplit(n_splits=10)

# Iterate through CV splits
fig, ax = plt.subplots()
for ii, (tr, tt) in enumerate(cv.split(train_1/train_1.max())):
    # Plot the training data on each iteration, to see the behavior of the CV
    ax.plot(train_1.index[tr], ii + train_1[tr]/train_1.max(), color='green')
    ax.plot(train_1.index[tt], ii + train_1[tt]/train_1.max(), color='orange')

ax.set(title='Training data on each CV iteration', ylabel='CV iteration')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d18070fedfd4> in <module>
#       7 # Iterate through CV splits
#       8 fig, ax = plt.subplots()
# ----> 9 for ii, (tr, tt) in enumerate(cv.split(store_train/store_train.max())):
#      10     # Plot the training data on each iteration, to see the behavior of the CV
#      11     ax.plot(store_train.index[tr], ii + store_train[tr]/store_train.max(), color='green')
#
# NameError: name 'store_train' is not defined

# %%
X = store_train

# Iterate through CV splits
n_splits = 20
cv = TimeSeriesSplit(n_splits=n_splits)

idx_lst = []
values_lst = []

for ii, (tr, tt) in tqdm(enumerate(cv.split(X))):
    # Fit the model on training data and collect the coefficients
    train = X[tr]
    test = X[tt]
    idx_lst.append(X.index[tt][0])
    error_lst = []
    predictions = predict_n_periods(series_=train, 
                    n_periods=len(test), 
                    model=GradientBoostingRegressor(n_estimators=20, learning_rate=0.5), 
                    num_periods_lagged=2,
                    num_periods_diffed=0,
                    weekday=True,
                    month=False)
    values_lst.append(mean_absolute_error(test,predictions))

# %%
pd.Series(values_lst, index=idx_lst).plot()

# %% [markdown]
# ## Parameter Grid Search

# %%
store[1500:].plot(label="original data")
pd.Series(predictions, index=test.index).plot(label="pred")
plt.legend();

# %%
generate_submission_file(predicted_mean_1.values, predicted_mean_2.values, predicted_mean_3.values)
