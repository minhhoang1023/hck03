# %%
import pandas as pd
import numpy as np
import utils
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
import utils 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import pandas as pd 
import numpy as np 
import statsmodels.api as sm  # <--- Yay! API! 
# %matplotlib inline 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 5)
from statsmodels.tsa.statespace.sarimax import SARIMAX

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)   
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
data = pd.read_csv('data/data.csv')

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data = data.set_index('date')
data = data.sort_index()

# %%
area_1 = data[data.variable == 'area_1'].drop('variable', axis = 1).dropna().sort_index()
area_2 = data[data.variable == 'area_2'].drop('variable', axis = 1).dropna().sort_index()
area_3 = data[data.variable == 'area_3'].drop('variable', axis = 1).dropna().sort_index()

# %%
train_1 = area_1[:-168]
train_2 = area_2[:-168]
train_3 = area_3[:-168]

test_1 = area_1[-168:]
test_2 = area_2[-168:]
test_3 = area_3[-168:]

# %%
area_1.plot()
area_2.plot()
area_3.plot()

# %%
#Area 1
mae_1 = sm.tsa.statespace.SARIMAX(train_1,
                                  order=(1, 1, 1),
                                  seasonal_order=(1, 1, 1, 12))

results_1 = mae_model_1.fit()
predictions_mae_model_1 = results_1.get_forecast(steps=168)
# Out:
# (17160, 2)
# (17160, 2)
# (17160, 2)

# %%
#Area 2
mae_2 = sm.tsa.statespace.SARIMAX(train_2,
                                  order=(1, 1, 1),
                                  seasonal_order=(1, 1, 1, 12))

results_2 = mae_model_2.fit()
predictions_mae_model_2 = results_2.get_forecast(steps=168)

# %%
#Area 3
mae_3 = sm.tsa.statespace.SARIMAX(train_3,
                                  order=(1, 1, 1),
                                  seasonal_order=(1, 1, 1, 12))

results_3 = mae_model_3.fit()
predictions_mae_model_3 = results_3.get_forecast(steps=168)

# %%
mae_1 = mean_absolute_error(test_1, predictions_mae_model_1)
mae_2 = mean_absolute_error(test_2, predictions_mae_model_2)
mae_3 = mean_absolute_error(test_3, predictions_mae_model_3)

# %%
generate_submission_file(results_1, results_2, results_3)
